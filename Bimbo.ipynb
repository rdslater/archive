# %%
# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
from sklearn import preprocessing
#sns.set_style('whitegrid')
# %matplotlib inline


# get bnp & test csv files as a DataFrame
train_df = pd.read_csv("C:/users/Robert/kaggle/Bimbo/data/train.csv",
                       nrows=1000000,
                       dtype={'Semana':np.uint16,'Agencia_ID':np.uint16, 'Canal_ID':np.uint16,'Ruta_SAK':np.uint16,
                              'Cliente_ID':np.uint16,'Producto_ID':np.uint16,'Venta_uni_hoy':np.uint16,'Venta_hoy':np.float64,
                              'Dev_uni_proxima':np.uint16,'Dev_proxima':np.float64,'Demanda_uni_equil':np.uint16})

#test_df = pd.read_csv("C:/users/Robert/kaggle/Bimbo/data/test.csv")

# %%
train_df.sort_values(['Agencia_ID','Canal_ID','Ruta_SAK', 'Cliente_ID','Producto_ID','Semana'])
# Out:
#           Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 540            3        1110         7      3301         665          323
# 32790674       6        1110         7      3301         665          323
# 42982569       7        1110         7      3301         665          323
# 53365372       8        1110         7      3301         665          323
# 11165776       4        1110         7      3301         665          325
# 22175256       5        1110         7      3301         665          325
# 541            3        1110         7      3301         665          328
# 11165777       4        1110         7      3301         665          328
# 42982570       7        1110         7      3301         665          328
# 542            3        1110         7      3301         665          641
# 11165778       4        1110         7      3301         665         1125
# 543            3        1110         7      3301         665         1146
# ...

# %%
pd.pivot_table(train_df,index=['Agencia_ID','Canal_ID','Ruta_SAK', 'Cliente_ID','Producto_ID'],columns=['Semana'],values=['Demanda_uni_equil'])
# Out:
#                                                     Demanda_uni_equil        \
# Semana                                                              3     4
# Agencia_ID Canal_ID Ruta_SAK Cliente_ID Producto_ID
# 1110       7        3301     665        323                       1.0   NaN
#                                         325                       NaN   1.0
#                                         328                       2.0   2.0
#                                         641                       4.0   NaN
#                                         1125                      NaN   0.0
#                                         1146                      7.0  10.0
#                                         1250                      NaN   NaN
#                                         1309                      NaN   NaN
#                                         1643                      NaN   NaN
#                                         1644                      NaN   NaN
# ...

# %%
a=pd.pivot_table(train_df,index=['Agencia_ID','Canal_ID','Ruta_SAK', 'Cliente_ID','Producto_ID'],columns=['Semana'],values=['Demanda_uni_equil'])

# %%
a.to_csv("a.csv")

# %%
train_pred=Y_pred =Grad_RandFor.predict_proba(train);
log_loss(target,train_pred)
# Out:
# 0.46959488649909886

# %%
from sklearn import metrics
from sklearn import cross_validation
ETC=ensemble.ExtraTreesClassifier(n_estimators=1000, random_state=0,verbose=1,n_jobs=4)
scores = cross_validation.cross_val_score(ETC,train, target,cv=5) 
print(scores)
# Out:
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   26.5s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=4)]: Done 1000 out of 1000 | elapsed:  2.3min finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done 1000 out of 1000 | elapsed:    5.1s finished
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   59.8s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=4)]: Done 1000 out of 1000 | elapsed:  2.3min finished
# ...

# %%
import pandas
from sklearn.ensemble import RandomForestClassifier
from boruta_py import BorutaPy



# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
forest = RandomForestClassifier(n_jobs=-1, class_weight='auto')

# define Boruta feature selection method
feat_selector = BorutaPy.BorutaPy(forest, n_estimators='auto', verbose=2)

# find all relevant features
feat_selector.fit(X, y)

# check selected features
feat_selector.support_

# check ranking of features
feat_selector.ranking_

# call transform() on X to filter it down to selected features
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-79bef302ea3c> in <module>()
#      12
#      13 # define Boruta feature selection method
# ---> 14 feat_selector = BorutaPy.BorutaPy(forest, n_estimators='auto', verbose=2)
#      15
#      16 # find all relevant features
#
# AttributeError: type object 'BorutaPy' has no attribute 'BorutaPy'

# %%
from pybrain.datasets import ClassificationDataSet
DS = ClassificationDataSet(111, nb_classes=2)
DS.setField('input', train)
DS.setField('target',target)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-40a0612a8594> in <module>()
#       2 DS = ClassificationDataSet(111, nb_classes=2)
#       3 DS.setField('input', train)
# ----> 4 DS.setField('target',target)
#
# C:\Anaconda3\lib\site-packages\pybrain\datasets\supervised.py in setField(self, label, arr, **kwargs)
#      60             self.indim = self.getDimension('input')
#      61         elif label == 'target':
# ---> 62             self.outdim = self.getDimension('target')
#      63
#      64     def _provideSequences(self):
#
# C:\Anaconda3\lib\site-packages\pybrain\datasets\dataset.py in getDimension(self, label)
#     146         `label`."""
#     147         try:
# --> 148             dim = self.data[label].shape[1]
#     149         except KeyError:
#     150             raise KeyError('dataset field %s not found.' % label)
#
# ...

# %%
inp=ds['input']

# %%
from pybrain.datasets            import ClassificationDataSet
from pybrain.utilities           import percentError
from pybrain.tools.shortcuts     import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
trainer = BackpropTrainer( net, dataset=DS,  verbose=True, weightdecay=0.01)

# %%
trainer.trainEpochs(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-c9db2457b9d6> in <module>()
# ----> 1 trainer.trainEpochs(1)
#
# C:\Anaconda3\lib\site-packages\pybrain\supervised\trainers\trainer.py in trainEpochs(self, epochs, *args, **kwargs)
#      35         Additional arguments are passed on to the train method."""
#      36         for dummy in range(epochs):
# ---> 37             self.train(*args, **kwargs)
#      38
#      39     def train(self):
#
# C:\Anaconda3\lib\site-packages\pybrain\supervised\trainers\backprop.py in train(self)
#      59         shuffle(shuffledSequences)
#      60         for seq in shuffledSequences:
# ---> 61             e, p = self._calcDerivs(seq)
#      62             errors += e
#      63             ponderation += p
#
# C:\Anaconda3\lib\site-packages\pybrain\supervised\trainers\backprop.py in _calcDerivs(self, seq)
# ...

# %%
# Out:
# array([ 0.44597047,  0.9111478 ,  0.7071496 , ...,  0.84333475,
#         0.78850436,  0.47413053])

# %%
from pylab import ion, ioff, figure, draw, contourf, clf, show, hold, plot
from scipy import diag, arange, meshgrid, where
from numpy.random import multivariate_normal
means = [(-1,0),(2,4),(3,1)]
cov = [diag([1,1]), diag([0.5,1.2]), diag([1.5,0.7])]
alldata = ClassificationDataSet(2, 1, nb_classes=3)
for n in range(400):
    for klass in range(3):
        input = multivariate_normal(means[klass],cov[klass])
        alldata.addSample(input, [klass])

# %%
tstdata, trndata = alldata.splitWithProportion( 0.25 )

# %%
from pybrain.datasets            import ClassificationDataSet
from pybrain.utilities           import percentError
from pybrain.tools.shortcuts     import buildNetwork
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure.modules   import SoftmaxLayer
trndata._convertToOneOfMany( )
tstdata._convertToOneOfMany( )
fnn = buildNetwork( trndata.indim, 5, trndata.outdim, outclass=SoftmaxLayer )
trainer = BackpropTrainer( fnn, dataset=trndata, momentum=0.1, verbose=True, weightdecay=0.01)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-30c9d57d22c7> in <module>()
#       4 from pybrain.supervised.trainers import BackpropTrainer
#       5 from pybrain.structure.modules   import SoftmaxLayer
# ----> 6 trndata._convertToOneOfMany( )
#       7 tstdata._convertToOneOfMany( )
#       8 fnn = buildNetwork( trndata.indim, 5, trndata.outdim, outclass=SoftmaxLayer )
#
# AttributeError: 'SupervisedDataSet' object has no attribute '_convertToOneOfMany'

# %%
ticks = arange(-3.,6.,0.2)
X, Y = meshgrid(ticks, ticks)
# need column vectors in dataset, not arrays
griddata = ClassificationDataSet(2,1, nb_classes=3)
for i in range(X.size):
    griddata.addSample([X.ravel()[i],Y.ravel()[i]], [0])
griddata._convertToOneOfMany()  # this is still needed to make the fnn feel comfy

# %%
for i in range(20):
    trainer.trainEpochs( 1 )
    trnresult = percentError( trainer.testOnClassData(),
                              trndata['class'] )
    tstresult = percentError( trainer.testOnClassData(
           dataset=tstdata ), tstdata['class'] )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-748c2ee79a7b> in <module>()
#       1 for i in range(20):
# ----> 2     trainer.trainEpochs( 1 )
#       3     trnresult = percentError( trainer.testOnClassData(),
#       4                               trndata['class'] )
#       5     tstresult = percentError( trainer.testOnClassData(
#
# C:\Anaconda3\lib\site-packages\pybrain\supervised\trainers\trainer.py in trainEpochs(self, epochs, *args, **kwargs)
#      35         Additional arguments are passed on to the train method."""
#      36         for dummy in range(epochs):
# ---> 37             self.train(*args, **kwargs)
#      38
#      39     def train(self):
#
# C:\Anaconda3\lib\site-packages\pybrain\supervised\trainers\backprop.py in train(self)
#      59         shuffle(shuffledSequences)
#      60         for seq in shuffledSequences:
# ...

# %%
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# C:\Anaconda3\lib\site-packages\sklearn\base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# C:\Anaconda3\lib\site-packages\sklearn\base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# C:\Anaconda3\lib\site-packages\sklearn\base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# C:\Anaconda3\lib\site-packages\sklearn\base.py:175: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   args, varargs, kw, default = inspect.getargspec(init)
# ...

# %%
# Out:
# array([[ 0.68574074,  0.31425926],
#        [ 0.3       ,  0.7       ],
#        [ 0.22      ,  0.78      ],
#        ...,
#        [ 0.04      ,  0.96      ],
#        [ 0.06      ,  0.94      ],
#        [ 0.52      ,  0.48      ]])
