# %%
# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
from sklearn import preprocessing
#sns.set_style('whitegrid')
# %matplotlib inline


# get bnp & test csv files as a DataFrame
#train = pd.read_csv("C:/users/Robert/kaggle/Bosch/data/train_categorical.csv",  nrows=2000,  dtype=str)
def pars_head(item):
    a=item.split('_')
    for i in range(0,3):
        a[i]=a[i].strip("LSF")
    return a

new_file= open("C:/users/Robert/kaggle/Bosch/data/new.csv", 'w')
headers="ID,Line,Station,Function,Value\n"
new_file.write(headers)
train=open("C:/users/Robert/kaggle/Bosch/data/train_categorical.csv", 'r')
headings=train.readline().rstrip()
headings=headings.split(',')
for line in train:
    data=train.readline().rstrip()
    data=data.split(',')
    for i in range(1,len(data)):
        if data[i]=='':
            continue
        else:
            build=[]
            build.append(data[0])
            build=build+pars_head(headings[i])
            build.append(data[i])
            new_file.write(','.join(build))
            new_file.write('\n')
train.close()
new_file.close()

# %%
            build=[]
            build.append(data[0])
            build=build+pars_head(headings[i])
            build.append(data[i])

# %%
import pandas as pd
import numpy as np
import re
    train = pd.read_csv("./kaggle/Bosch/data/train_date.csv", chunksize=100000)
train_new=pd.DataFrame()
toggle=0
for chunk in train:
    print("-",end='')
    if toggle == 0:
        a=chunk.columns.values.tolist()
        myString = '(L[0-9]*_S[0-9]*_) *'
        pattern1 = r'\b' + re.escape(myString) + r'\b'
        pattern=re.compile(myString)
        indices = [i for i, x in enumerate(a) if re.search(pattern, x)]
        i=0
        for item in a:
            if 'L' in item:
                a[i]=re.search(pattern, a[i]).group(1)
            i=i+1
        a=list(set(a))
    new_train=pd.DataFrame()
    for item in a:
        if (item=='Id' )| (item=='Response'):
            new_train[item]=chunk[item]
        else:
            spike_cols = [col for col in chunk.columns if item in col]
            mean=item+'mean'
            nacount=item+'NAcount'
            max_v=item+'max'
            min_v=item+'min'
            new_train[mean]=chunk[spike_cols].mean(axis=1)
            new_train[nacount]=chunk[spike_cols].isnull().sum(axis=1)
            new_train[max_v]=chunk[spike_cols].max(axis=1)
            new_train[min_v]=chunk[spike_cols].min(axis=1)
            cols=new_train.columns.values.tolist()
            cols.sort()
            new_train=new_train[cols]
        
    if toggle==0:
        new_train.to_csv("./kaggle/Bosch//data/train_num_smry.csv",mode='w',index=False,header=True)
        toggle=1
    else:
        new_train.to_csv( "./kaggle/Bosch//data/train_num_smry.csv",mode='a',index=False,header=False)
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -

# %%
from sklearn.ensemble import ExtraTreesClassifier

target=train['Response']
train.drop(['Response','Id'],axis=1)
# Out:
#          L0_S0_NAcount  L0_S0_max  L0_S0_mean  L0_S0_min  L0_S10_NAcount  \
# 0                    0      0.118   -0.053000     -0.273              12
# 1                   12        NaN         NaN        NaN              12
# 2                    0      0.250    0.029333     -0.225               0
# 3                    0      0.330    0.027583     -0.253               0
# 4                    0      0.330    0.053333     -0.169              12
# 5                    0      0.312    0.071000     -0.035               0
# 6                   12        NaN         NaN        NaN              12
# 7                   12        NaN         NaN        NaN              12
# 8                    0      0.163   -0.059000     -0.220               0
# 9                   12        NaN         NaN        NaN              12
# 10                   0      0.209    0.066167     -0.072               0
# 11                   0      0.088   -0.152500     -0.384              12
# 12                   0      0.367    0.001000     -0.303              12
# 13                   0      0.152   -0.001583     -0.216              12
# 14                   0      0.118   -0.044000     -0.197              12
# 15                   0      0.252   -0.021750     -0.294              12
# 16                  12        NaN         NaN        NaN              12
# 17                   0      0.286    0.016667     -0.339               0
# 18                  12        NaN         NaN        NaN              12
# 19                   0      0.348    0.102333     -0.112               0
# 20                  12        NaN         NaN        NaN              12
# 21                  12        NaN         NaN        NaN              12
# 22                   0      0.215    0.042583     -0.072              12
# 23                   0      0.152   -0.029833     -0.197               0
# 24                  12        NaN         NaN        NaN              12
# 25                   0      0.312    0.077250     -0.097               0
# 26                   0      0.170   -0.011500     -0.216               0
# 27                   0      0.330    0.138417     -0.168              12
# 28                  12        NaN         NaN        NaN              12
# 29                  12        NaN         NaN        NaN              12
# ...                ...        ...         ...        ...             ...
# 1183717              0      0.330    0.003667     -0.248              12
# 1183718             12        NaN         NaN        NaN              12
# 1183719              0      0.099   -0.053167     -0.215              12
# 1183720              0      0.213   -0.047083     -0.339               0
# 1183721             12        NaN         NaN        NaN              12
# 1183722             12        NaN         NaN        NaN              12
# 1183723             12        NaN         NaN        NaN              12
# 1183724              0      0.117   -0.058833     -0.246              12
# 1183725              0      0.118   -0.024000     -0.179              12
# 1183726             12        NaN         NaN        NaN              12
# 1183727             12        NaN         NaN        NaN              12
# 1183728              0      0.161    0.046417     -0.072               0
# 1183729             12        NaN         NaN        NaN              12
# 1183730             12        NaN         NaN        NaN              12
# 1183731              0      0.118   -0.062167     -0.233              12
# 1183732             12        NaN         NaN        NaN              12
# 1183733              0      0.015   -0.165417     -0.384               0
# 1183734              0      0.254    0.016083     -0.138               0
# 1183735             12        NaN         NaN        NaN              12
# 1183736              0      0.238    0.058833     -0.072              12
# 1183737             12        NaN         NaN        NaN              12
# 1183738              0      0.163   -0.016167     -0.286              12
# 1183739             12        NaN         NaN        NaN              12
# 1183740              0      0.367    0.003667     -0.302               0
# 1183741             12        NaN         NaN        NaN              12
# 1183742              0      0.178    0.052750     -0.032              12
# 1183743             12        NaN         NaN        NaN              12
# 1183744              0      0.214   -0.015250     -0.343              12
# 1183745              0      0.275    0.009750     -0.179              12
# 1183746              0      0.161    0.031083     -0.072               0
#
#          L0_S10_max  L0_S10_mean  L0_S10_min  L0_S11_NAcount  L0_S11_max  \
# 0               NaN          NaN         NaN               0       0.260
# 1               NaN          NaN         NaN              12         NaN
# 2             0.105     0.003917      -0.047              12         NaN
# 3             0.139     0.004333      -0.049              12         NaN
# 4               NaN          NaN         NaN               0       0.238
# 5             0.010    -0.011000      -0.061              12         NaN
# 6               NaN          NaN         NaN              12         NaN
# 7               NaN          NaN         NaN              12         NaN
# 8             0.051    -0.023917      -0.233              12         NaN
# 9               NaN          NaN         NaN              12         NaN
# 10            0.079     0.016833      -0.013              12         NaN
# 11              NaN          NaN         NaN              12         NaN
# 12              NaN          NaN         NaN              12         NaN
# 13              NaN          NaN         NaN              12         NaN
# 14              NaN          NaN         NaN              12         NaN
# 15              NaN          NaN         NaN              12         NaN
# 16              NaN          NaN         NaN              12         NaN
# 17            0.162     0.014500      -0.051              12         NaN
# 18              NaN          NaN         NaN              12         NaN
# 19            0.056     0.001000      -0.101              12         NaN
# 20              NaN          NaN         NaN              12         NaN
# 21              NaN          NaN         NaN              12         NaN
# 22              NaN          NaN         NaN              12         NaN
# 23            0.084     0.006250      -0.049              12         NaN
# 24              NaN          NaN         NaN              12         NaN
# 25            0.089     0.014417      -0.036              12         NaN
# 26            0.138     0.006417      -0.026              12         NaN
# 27              NaN          NaN         NaN               0       0.108
# 28              NaN          NaN         NaN              12         NaN
# 29              NaN          NaN         NaN              12         NaN
# ...             ...          ...         ...             ...         ...
# 1183717         NaN          NaN         NaN              12         NaN
# 1183718         NaN          NaN         NaN              12         NaN
# 1183719         NaN          NaN         NaN              12         NaN
# 1183720       0.141     0.028500      -0.012              12         NaN
# 1183721         NaN          NaN         NaN              12         NaN
# 1183722         NaN          NaN         NaN              12         NaN
# 1183723         NaN          NaN         NaN              12         NaN
# 1183724         NaN          NaN         NaN               0       0.209
# 1183725         NaN          NaN         NaN               0       0.034
# 1183726         NaN          NaN         NaN              12         NaN
# 1183727         NaN          NaN         NaN              12         NaN
# 1183728       0.014    -0.013500      -0.039              12         NaN
# 1183729         NaN          NaN         NaN              12         NaN
# 1183730         NaN          NaN         NaN              12         NaN
# 1183731         NaN          NaN         NaN               0       0.159
# 1183732         NaN          NaN         NaN              12         NaN
# 1183733       0.081     0.001750      -0.038              12         NaN
# 1183734       0.151     0.020417      -0.059              12         NaN
# 1183735         NaN          NaN         NaN              12         NaN
# 1183736         NaN          NaN         NaN              12         NaN
# 1183737         NaN          NaN         NaN              12         NaN
# 1183738         NaN          NaN         NaN               0       0.188
# 1183739         NaN          NaN         NaN              12         NaN
# 1183740       0.130     0.010333      -0.020              12         NaN
# 1183741         NaN          NaN         NaN              12         NaN
# 1183742         NaN          NaN         NaN              12         NaN
# 1183743         NaN          NaN         NaN              12         NaN
# 1183744         NaN          NaN         NaN              12         NaN
# 1183745         NaN          NaN         NaN              12         NaN
# 1183746       0.041     0.003333      -0.041              12         NaN
#
#             ...      L3_S49_mean  L3_S49_min  L3_S50_NAcount  L3_S50_max  \
# 0           ...              NaN         NaN               7         NaN
# 1           ...              NaN         NaN               7         NaN
# 2           ...              NaN         NaN               7         NaN
# 3           ...              NaN         NaN               7         NaN
# 4           ...              NaN         NaN               7         NaN
# 5           ...              NaN         NaN               7         NaN
# 6           ...              NaN         NaN               7         NaN
# 7           ...              NaN         NaN               7         NaN
# 8           ...              NaN         NaN               7         NaN
# 9           ...              NaN         NaN               7         NaN
# 10          ...              NaN         NaN               7         NaN
# 11          ...              NaN         NaN               7         NaN
# 12          ...              NaN         NaN               7         NaN
# 13          ...              NaN         NaN               7         NaN
# 14          ...              NaN         NaN               7         NaN
# 15          ...              NaN         NaN               7         NaN
# 16          ...              NaN         NaN               7         NaN
# 17          ...              NaN         NaN               7         NaN
# 18          ...              NaN         NaN               7         NaN
# 19          ...              NaN         NaN               7         NaN
# 20          ...              NaN         NaN               7         NaN
# 21          ...              NaN         NaN               7         NaN
# 22          ...              NaN         NaN               7         NaN
# 23          ...              NaN         NaN               7         NaN
# 24          ...              NaN         NaN               7         NaN
# 25          ...              NaN         NaN               7         NaN
# 26          ...         0.034429      -0.009               7         NaN
# 27          ...              NaN         NaN               7         NaN
# 28          ...              NaN         NaN               7         NaN
# 29          ...              NaN         NaN               7         NaN
# ...         ...              ...         ...             ...         ...
# 1183717     ...              NaN         NaN               7         NaN
# 1183718     ...              NaN         NaN               7         NaN
# 1183719     ...              NaN         NaN               7         NaN
# 1183720     ...              NaN         NaN               7         NaN
# 1183721     ...              NaN         NaN               7         NaN
# 1183722     ...              NaN         NaN               7         NaN
# 1183723     ...              NaN         NaN               7         NaN
# 1183724     ...              NaN         NaN               7         NaN
# 1183725     ...              NaN         NaN               7         NaN
# 1183726     ...              NaN         NaN               7         NaN
# 1183727     ...              NaN         NaN               7         NaN
# 1183728     ...              NaN         NaN               7         NaN
# 1183729     ...              NaN         NaN               7         NaN
# 1183730     ...              NaN         NaN               7         NaN
# 1183731     ...              NaN         NaN               7         NaN
# 1183732     ...              NaN         NaN               7         NaN
# 1183733     ...              NaN         NaN               7         NaN
# 1183734     ...              NaN         NaN               7         NaN
# 1183735     ...              NaN         NaN               7         NaN
# 1183736     ...              NaN         NaN               7         NaN
# 1183737     ...              NaN         NaN               7         NaN
# 1183738     ...              NaN         NaN               7         NaN
# 1183739     ...              NaN         NaN               7         NaN
# 1183740     ...              NaN         NaN               7         NaN
# 1183741     ...              NaN         NaN               7         NaN
# 1183742     ...              NaN         NaN               7         NaN
# 1183743     ...              NaN         NaN               7         NaN
# 1183744     ...              NaN         NaN               7         NaN
# 1183745     ...              NaN         NaN               7         NaN
# 1183746     ...              NaN         NaN               7         NaN
#
#          L3_S50_mean  L3_S50_min  L3_S51_NAcount  L3_S51_max  L3_S51_mean  \
# 0                NaN         NaN               4         NaN          NaN
# 1                NaN         NaN               4         NaN          NaN
# 2                NaN         NaN               4         NaN          NaN
# 3                NaN         NaN               4         NaN          NaN
# 4                NaN         NaN               4         NaN          NaN
# 5                NaN         NaN               4         NaN          NaN
# 6                NaN         NaN               4         NaN          NaN
# 7                NaN         NaN               4         NaN          NaN
# 8                NaN         NaN               4         NaN          NaN
# 9                NaN         NaN               4         NaN          NaN
# 10               NaN         NaN               4         NaN          NaN
# 11               NaN         NaN               4         NaN          NaN
# 12               NaN         NaN               4         NaN          NaN
# 13               NaN         NaN               4         NaN          NaN
# 14               NaN         NaN               4         NaN          NaN
# 15               NaN         NaN               4         NaN          NaN
# 16               NaN         NaN               4         NaN          NaN
# 17               NaN         NaN               4         NaN          NaN
# 18               NaN         NaN               4         NaN          NaN
# 19               NaN         NaN               4         NaN          NaN
# 20               NaN         NaN               4         NaN          NaN
# 21               NaN         NaN               4         NaN          NaN
# 22               NaN         NaN               4         NaN          NaN
# 23               NaN         NaN               4         NaN          NaN
# 24               NaN         NaN               4         NaN          NaN
# 25               NaN         NaN               4         NaN          NaN
# 26               NaN         NaN               0         0.0          0.0
# 27               NaN         NaN               4         NaN          NaN
# 28               NaN         NaN               4         NaN          NaN
# 29               NaN         NaN               4         NaN          NaN
# ...              ...         ...             ...         ...          ...
# 1183717          NaN         NaN               4         NaN          NaN
# 1183718          NaN         NaN               4         NaN          NaN
# 1183719          NaN         NaN               4         NaN          NaN
# 1183720          NaN         NaN               4         NaN          NaN
# 1183721          NaN         NaN               4         NaN          NaN
# 1183722          NaN         NaN               4         NaN          NaN
# 1183723          NaN         NaN               4         NaN          NaN
# 1183724          NaN         NaN               4         NaN          NaN
# 1183725          NaN         NaN               4         NaN          NaN
# 1183726          NaN         NaN               4         NaN          NaN
# 1183727          NaN         NaN               4         NaN          NaN
# 1183728          NaN         NaN               4         NaN          NaN
# 1183729          NaN         NaN               4         NaN          NaN
# 1183730          NaN         NaN               4         NaN          NaN
# 1183731          NaN         NaN               4         NaN          NaN
# 1183732          NaN         NaN               4         NaN          NaN
# 1183733          NaN         NaN               4         NaN          NaN
# 1183734          NaN         NaN               4         NaN          NaN
# 1183735          NaN         NaN               4         NaN          NaN
# 1183736          NaN         NaN               4         NaN          NaN
# 1183737          NaN         NaN               4         NaN          NaN
# 1183738          NaN         NaN               4         NaN          NaN
# 1183739          NaN         NaN               4         NaN          NaN
# 1183740          NaN         NaN               4         NaN          NaN
# 1183741          NaN         NaN               4         NaN          NaN
# 1183742          NaN         NaN               4         NaN          NaN
# 1183743          NaN         NaN               4         NaN          NaN
# 1183744          NaN         NaN               4         NaN          NaN
# 1183745          NaN         NaN               4         NaN          NaN
# 1183746          NaN         NaN               4         NaN          NaN
#
#          L3_S51_min
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              0.0
# 27              NaN
# 28              NaN
# 29              NaN
# ...             ...
# 1183717         NaN
# 1183718         NaN
# 1183719         NaN
# 1183720         NaN
# 1183721         NaN
# 1183722         NaN
# 1183723         NaN
# 1183724         NaN
# 1183725         NaN
# 1183726         NaN
# 1183727         NaN
# 1183728         NaN
# 1183729         NaN
# 1183730         NaN
# 1183731         NaN
# 1183732         NaN
# 1183733         NaN
# 1183734         NaN
# 1183735         NaN
# 1183736         NaN
# 1183737         NaN
# 1183738         NaN
# 1183739         NaN
# 1183740         NaN
# 1183741         NaN
# 1183742         NaN
# 1183743         NaN
# 1183744         NaN
# 1183745         NaN
# 1183746         NaN
#
# [1183747 rows x 200 columns]

# %%
import pandas as pd
train = pd.read_csv("./kaggle/Bosch/data/train_date.csv", nrows=100)

# %%
import pandas as pd
import numpy as np
import re
crazy=[]
test = pd.read_csv("./kaggle/Bosch/data/train_date.csv", chunksize=100000)
test_new=pd.DataFrame()
toggle=0
for chunk in test:
    print("-",end='')
    if toggle == 0:
        a=chunk.columns.values.tolist()
        myString = '(L[0-9]*_S[0-9]*_) *'
        pattern1 = r'\b' + re.escape(myString) + r'\b'
        pattern=re.compile(myString)
        indices = [i for i, x in enumerate(a) if re.search(pattern, x)]
        i=0
        for item in a:
            if 'L' in item:
                a[i]=re.search(pattern, a[i]).group(1)
            i=i+1
        a=list(set(a))
    new_test=pd.DataFrame()
    for item in a:
        if (item=='Id' )| (item=='Response'):
            new_test[item]=chunk[item]
        else:
            spike_cols = [col for col in chunk.columns if item in col]
            mean=item+'mean'
            nacount=item+'NAcount'
            max_v=item+'max'
            min_v=item+'min'
            std_d=item+'std'
            new_test[mean]=chunk[spike_cols].mean(axis=1)
            new_test[nacount]=chunk[spike_cols].isnull().sum(axis=1)
            if item in ['L1_S24_','L1_S25_']:
                new_test[std_d]=chunk[spike_cols].std(axis=1)
                new_test[max_v]=chunk[spike_cols].max(axis=1)
                new_test[min_v]=chunk[spike_cols].min(axis=1)
            cols=new_test.columns.values.tolist()
            cols.sort()
            new_test=new_test[cols]

    if toggle==0:
        new_test.to_csv("./kaggle/Bosch//data/train_date_smry.csv",mode='w',index=False,header=True)
        toggle=1
    else:
        new_test.to_csv( "./kaggle/Bosch//data/train_date_smry.csv",mode='a',index=False,header=False)
# Out:
# ------------

# %%
data.to_csv("./kaggle/Bosch//data/train_date_smry.csv",mode='w',index=False,header=True)

# %%
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
train=pd.read_csv("./kaggle/Bosch//data/train_numeric.csv", nrows=50000, index_col='Id')
train2=pd.read_csv("./kaggle/Bosch//data/train_categorical.csv", nrows=150000, dtype=str, index_col='Id')

# %%
a
# Out:
# ['L3_S39_',
#  'L0_S4_',
#  'L3_S43_',
#  'L0_S13_',
#  'L3_S35_',
#  'L0_S12_',
#  'L1_S25_',
#  'L3_S36_',
#  'L2_S27_',
#  'L1_S24_',
#  'L0_S19_',
#  'L3_S42_',
#  'L3_S51_',
#  'L0_S6_',
#  'L2_S26_',
#  'L3_S50_',
#  'L0_S20_',
#  'L3_S32_',
#  'L0_S23_',
#  'L0_S2_',
#  'L3_S47_',
#  'L3_S49_',
#  'L0_S7_',
#  'L0_S8_',
#  'L0_S21_',
#  'L3_S33_',
#  'L0_S3_',
#  'L0_S9_',
#  'L0_S22_',
#  'L3_S46_',
#  'L0_S17_',
#  'L3_S48_',
#  'L0_S1_',
#  'L3_S29_',
#  'L3_S34_',
#  'L3_S44_',
#  'L0_S18_',
#  'L3_S30_',
#  'L3_S41_',
#  'L0_S0_',
#  'L0_S11_',
#  'L3_S38_',
#  'L3_S37_',
#  'L0_S5_',
#  'L3_S40_',
#  'L0_S14_',
#  'L0_S10_',
#  'Id',
#  'L0_S16_',
#  'L3_S31_',
#  'L2_S28_',
#  'L3_S45_',
#  'L0_S15_']

# %%
result = pd.concat([df, df2], axis=1,)

# %%
cols = result.columns.tolist()
cols.sort()

# %%
result=result[cols]

# %%
result=result.drop([1,2,3],axis=1)

# %%
#train=pd.read_csv("./kaggle/Bosch//data/train_numeric.csv", chunksize=100000, index_col='Id')
train2=pd.read_csv("./kaggle/Bosch/data/train_categorical.csv",chunksize=100000, dtype=str, index_col='Id')
df2=pd.DataFrame()
for chunk in train2:
    num=chunk
    cat=num.filter(regex=("L0_S2_.*"))
    df2=df2.append(cat)
    #result.filter(regex=("L0_S2_.*"))[result.L0_S2_F35.notnull()]

# %%
chunk
# Out:
# 'L0_S1_F25'

# %%
df2.shape
# Out:
# (1183747, 18)

# %%
df.shape
# Out:
# (1183747, 9)

# %%
result[result.L0_S2_F36==-.308]
# Out:
#          L0_S2_F32 L0_S2_F33 L0_S2_F35  L0_S2_F36 L0_S2_F37 L0_S2_F39  \
# Id
# 16927        0.787        T1       T32     -0.308        T1       T32
# 20833        0.787       NaN       NaN     -0.308       NaN       NaN
# 21591        0.787        T1       T32     -0.308        T1       T32
# 35611        0.787        T1       T32     -0.308        T1       T32
# 38775        0.787        T1       T32     -0.308        T1       T32
# 39584        0.787        T1       T32     -0.308        T1       T32
# 42908        0.787        T1       T32     -0.308        T1       T32
# 54135        0.787        T1       T32     -0.308        T1       T32
# 79624        0.787       NaN       NaN     -0.308       NaN       NaN
# 87872        0.787        T1       T32     -0.308        T1       T32
# 89379        0.787        T1       T32     -0.308        T1       T32
# 116226       0.787        T1       T64     -0.308        T1       T64
# 129252       0.787        T1       T32     -0.308        T1       T32
# 135864       0.787        T1       T32     -0.308        T1       T32
# 142558       0.787        T1       T64     -0.308        T1       T64
# 160626       0.787        T1       T32     -0.308        T1       T32
# 163119       0.787        T1       T32     -0.308        T1       T32
# 166293       0.787        T1       T32     -0.308        T1       T32
# 176910       0.787        T1       T32     -0.308        T1       T32
# 176999       0.787        T1       T64     -0.308        T1       T64
# 202641       0.787       NaN       NaN     -0.308       NaN       NaN
# 207882       0.787        T1       T32     -0.308        T1       T32
# 218836       0.787        T1      T128     -0.308        T1      T128
# 235323       0.787        T1       T32     -0.308        T1       T32
# 242323       0.787        T1       T32     -0.308        T1       T32
# 249307       0.787       NaN       NaN     -0.308       NaN       NaN
# 251132       0.787       NaN       NaN     -0.308       NaN       NaN
# 255414       0.787       NaN       NaN     -0.308       NaN       NaN
# 257492       0.787        T1       T32     -0.308        T1       T32
# 263378       0.787        T1       T32     -0.308        T1       T32
# ...            ...       ...       ...        ...       ...       ...
# 2089262      0.787        T1       T32     -0.308        T1       T32
# 2089372      0.787        T1       T32     -0.308        T1       T32
# 2114331      0.787       NaN       NaN     -0.308       NaN       NaN
# 2133578      0.787        T1       T32     -0.308        T1       T32
# 2134041      0.787        T1       T32     -0.308        T1       T32
# 2134043      0.787        T1       T32     -0.308        T1       T32
# 2169719      0.787       NaN       NaN     -0.308       NaN       NaN
# 2174411      0.787        T1       T32     -0.308        T1       T32
# 2200679      0.787       NaN       NaN     -0.308       NaN       NaN
# 2202831      0.787        T1       T32     -0.308        T1       T32
# 2208215      0.787        T1       T32     -0.308        T1       T32
# 2211206      0.787       NaN       NaN     -0.308       NaN       NaN
# 2216567      0.787        T1       T32     -0.308        T1       T32
# 2240187      0.787        T1       T64     -0.308        T1       T64
# 2245875      0.787        T1       T32     -0.308        T1       T32
# 2254862      0.787        T1       T32     -0.308        T1       T32
# 2260314      0.787       NaN       NaN     -0.308       NaN       NaN
# 2262813      0.787        T1       T32     -0.308        T1       T32
# 2280603      0.787        T1       T32     -0.308        T1       T32
# 2284949      0.787       NaN       NaN     -0.308       NaN       NaN
# 2295106      0.787        T1       T32     -0.308        T1       T32
# 2304717      0.787        T1       T32     -0.308        T1       T32
# 2304749      0.787        T1      T128     -0.308        T1      T128
# 2310823      0.787        T1      T128     -0.308        T1      T128
# 2315493      0.787        T1       T32     -0.308        T1       T32
# 2326348      0.787        T1      T128     -0.308        T1      T128
# 2332054      0.787        T1       T32     -0.308        T1       T32
# 2334392      0.787       NaN       NaN     -0.308       NaN       NaN
# 2335856      0.787        T1       T32     -0.308        T1       T32
# 2364287      0.787        T1       T32     -0.308        T1       T32
#
#          L0_S2_F40 L0_S2_F41 L0_S2_F43  L0_S2_F44    ...    L0_S2_F55  \
# Id                                                   ...
# 16927        0.808        T1       T32     -0.373    ...          T32
# 20833        0.808       NaN       NaN     -0.373    ...          NaN
# 21591        0.808        T1       T32     -0.373    ...          T32
# 35611        0.808        T1       T32     -0.373    ...          T32
# 38775        0.808        T1       T32     -0.373    ...          T32
# 39584        0.808        T1       T32     -0.373    ...          T32
# 42908        0.808        T1       T32     -0.373    ...          T32
# 54135        0.808        T1       T32     -0.373    ...          T32
# 79624        0.808       NaN       NaN     -0.373    ...          NaN
# 87872        0.808        T1       T32     -0.373    ...          T32
# 89379        0.808        T1       T32     -0.373    ...          T32
# 116226       0.808        T1       T64     -0.373    ...          T64
# 129252       0.808        T1       T32     -0.373    ...          T32
# 135864       0.808        T1       T32     -0.373    ...          T32
# 142558       0.808        T1       T64     -0.373    ...          T64
# 160626       0.808        T1       T32     -0.373    ...          T32
# 163119       0.808        T1       T32     -0.373    ...          T32
# 166293       0.808        T1       T32     -0.373    ...          T32
# 176910       0.808        T1       T32     -0.373    ...          T32
# 176999       0.808        T1       T64     -0.373    ...          T64
# 202641       0.808       NaN       NaN     -0.373    ...          NaN
# 207882       0.808        T1       T32     -0.373    ...          T32
# 218836       0.808        T1      T128     -0.373    ...         T128
# 235323       0.808        T1       T32     -0.373    ...          T32
# 242323       0.808        T1       T32     -0.373    ...          T32
# 249307       0.808       NaN       NaN     -0.373    ...          NaN
# 251132       0.808       NaN       NaN     -0.373    ...          NaN
# 255414       0.808       NaN       NaN     -0.373    ...          NaN
# 257492       0.808        T1       T32     -0.373    ...          T32
# 263378       0.808        T1       T32     -0.373    ...          T32
# ...            ...       ...       ...        ...    ...          ...
# 2089262      0.808        T1       T32     -0.373    ...          T32
# 2089372      0.808        T1       T32     -0.373    ...          T32
# 2114331      0.808       NaN       NaN     -0.373    ...          NaN
# 2133578      0.808        T1       T32     -0.373    ...          T32
# 2134041      0.808        T1       T32     -0.373    ...          T32
# 2134043      0.808        T1       T32     -0.373    ...          T32
# 2169719      0.808       NaN       NaN     -0.373    ...          NaN
# 2174411      0.808        T1       T32     -0.373    ...          T32
# 2200679      0.808       NaN       NaN     -0.373    ...          NaN
# 2202831      0.808        T1       T32     -0.373    ...          T32
# 2208215      0.808        T1       T32     -0.373    ...          T32
# 2211206      0.808       NaN       NaN     -0.373    ...          NaN
# 2216567      0.808        T1       T32     -0.373    ...          T32
# 2240187      0.808        T1       T64     -0.373    ...          T64
# 2245875      0.808        T1       T32     -0.373    ...          T32
# 2254862      0.808        T1       T32     -0.373    ...          T32
# 2260314      0.808       NaN       NaN     -0.373    ...          NaN
# 2262813      0.808        T1       T32     -0.373    ...          T32
# 2280603      0.808        T1       T32     -0.373    ...          T32
# 2284949      0.808       NaN       NaN     -0.373    ...          NaN
# 2295106      0.808        T1       T32     -0.373    ...          T32
# 2304717      0.808        T1       T32     -0.373    ...          T32
# 2304749      0.808        T1      T128     -0.373    ...         T128
# 2310823      0.808        T1      T128     -0.373    ...         T128
# 2315493      0.808        T1       T32     -0.373    ...          T32
# 2326348      0.808        T1      T128     -0.373    ...         T128
# 2332054      0.808        T1       T32     -0.373    ...          T32
# 2334392      0.808       NaN       NaN     -0.373    ...          NaN
# 2335856      0.808        T1       T32     -0.373    ...          T32
# 2364287      0.808        T1       T32     -0.373    ...          T32
#
#         L0_S2_F56  L0_S2_F57 L0_S2_F59 L0_S2_F60  L0_S2_F61 L0_S2_F63  \
# Id
# 16927        0.81         T1       T32    -0.365         T1       T32
# 20833        0.81        NaN       NaN    -0.365        NaN       NaN
# 21591        0.81         T1       T32    -0.365         T1       T32
# 35611        0.81         T1       T32    -0.365         T1       T32
# 38775        0.81         T1       T32    -0.365         T1       T32
# 39584        0.81         T1       T32    -0.365         T1       T32
# 42908        0.81         T1       T32    -0.365         T1       T32
# 54135        0.81         T1       T32    -0.365         T1       T32
# 79624        0.81        NaN       NaN    -0.365        NaN       NaN
# 87872        0.81         T1       T32    -0.365         T1       T32
# 89379        0.81         T1       T32    -0.365         T1       T32
# 116226       0.81         T1       T64    -0.365         T1       T64
# 129252       0.81         T1       T32    -0.365         T1       T32
# 135864       0.81         T1       T32    -0.365         T1       T32
# 142558       0.81         T1       T64    -0.365         T1       T64
# 160626       0.81         T1       T32    -0.365         T1       T32
# 163119       0.81         T1       T32    -0.365         T1       T32
# 166293       0.81         T1       T32    -0.365         T1       T32
# 176910       0.81         T1       T32    -0.365         T1       T32
# 176999       0.21         T1       T64    -0.218         T1       T64
# 202641       0.81        NaN       NaN    -0.365        NaN       NaN
# 207882       0.81         T1       T32    -0.365         T1       T32
# 218836       0.21         T1      T128    -0.213         T1      T128
# 235323       0.81         T1       T32    -0.365         T1       T32
# 242323       0.81         T1       T32    -0.365         T1       T32
# 249307       0.81        NaN       NaN    -0.365        NaN       NaN
# 251132       0.11        NaN       NaN     0.476        NaN       NaN
# 255414       0.81        NaN       NaN    -0.365        NaN       NaN
# 257492       0.81         T1       T32    -0.365         T1       T32
# 263378       0.81         T1       T32    -0.365         T1       T32
# ...           ...        ...       ...       ...        ...       ...
# 2089262      0.81         T1       T32    -0.365         T1       T32
# 2089372      0.81         T1       T32    -0.365         T1       T32
# 2114331      0.81        NaN       NaN    -0.365        NaN       NaN
# 2133578      0.81         T1       T32    -0.365         T1       T32
# 2134041      0.81         T1       T32    -0.365         T1       T32
# 2134043      0.81         T1       T32    -0.365         T1       T32
# 2169719      0.81        NaN       NaN    -0.365        NaN       NaN
# 2174411      0.81         T1       T32    -0.365         T1       T32
# 2200679      0.81        NaN       NaN    -0.365        NaN       NaN
# 2202831      0.81         T1       T32    -0.365         T1       T32
# 2208215      0.81         T1       T32    -0.365         T1       T32
# 2211206      0.81        NaN       NaN    -0.365        NaN       NaN
# 2216567      0.81         T1       T32    -0.365         T1       T32
# 2240187      0.81         T1       T64    -0.365         T1       T64
# 2245875      0.81         T1       T32    -0.365         T1       T32
# 2254862      0.81         T1       T32    -0.365         T1       T32
# 2260314      0.81        NaN       NaN    -0.365        NaN       NaN
# 2262813      0.81         T1       T32    -0.365         T1       T32
# 2280603      0.81         T1       T32    -0.365         T1       T32
# 2284949      0.81        NaN       NaN    -0.365        NaN       NaN
# 2295106      0.81         T1       T32    -0.365         T1       T32
# 2304717      0.81         T1       T32    -0.365         T1       T32
# 2304749      0.11         T1      T128     0.025         T1      T128
# 2310823      0.11         T1      T128    -0.126         T1      T128
# 2315493      0.81         T1       T32    -0.365         T1       T32
# 2326348      0.11         T1      T128    -0.067         T1      T128
# 2332054      0.81         T1       T32    -0.365         T1       T32
# 2334392      0.81        NaN       NaN    -0.365        NaN       NaN
# 2335856      0.81         T1       T32    -0.365         T1       T32
# 2364287      0.81         T1       T32    -0.365         T1       T32
#
#         L0_S2_F64  L0_S2_F65 L0_S2_F67
# Id
# 16927      -0.176         T1       T32
# 20833      -0.176        NaN       NaN
# 21591      -0.176         T1       T32
# 35611      -0.176         T1       T32
# 38775      -0.176         T1       T32
# 39584      -0.176         T1       T32
# 42908      -0.176         T1       T32
# 54135      -0.176         T1       T32
# 79624      -0.003        NaN       NaN
# 87872      -0.176         T1       T32
# 89379      -0.176         T1       T32
# 116226      0.008         T1       T64
# 129252     -0.176         T1       T32
# 135864     -0.176         T1       T32
# 142558      0.003         T1       T64
# 160626     -0.176         T1       T32
# 163119     -0.176         T1       T32
# 166293     -0.176         T1       T32
# 176910     -0.176         T1       T32
# 176999      0.761         T1       T64
# 202641     -0.176        NaN       NaN
# 207882     -0.176         T1       T32
# 218836     -0.078         T1      T128
# 235323     -0.176         T1       T32
# 242323     -0.176         T1       T32
# 249307     -0.176        NaN       NaN
# 251132      0.009        NaN       NaN
# 255414     -0.176        NaN       NaN
# 257492     -0.176         T1       T32
# 263378     -0.176         T1       T32
# ...           ...        ...       ...
# 2089262    -0.176         T1       T32
# 2089372    -0.176         T1       T32
# 2114331    -0.176        NaN       NaN
# 2133578    -0.176         T1       T32
# 2134041    -0.176         T1       T32
# 2134043    -0.176         T1       T32
# 2169719    -0.176        NaN       NaN
# 2174411    -0.176         T1       T32
# 2200679    -0.176        NaN       NaN
# 2202831    -0.176         T1       T32
# 2208215    -0.176         T1       T32
# 2211206    -0.176        NaN       NaN
# 2216567    -0.176         T1       T32
# 2240187     0.009         T1       T64
# 2245875    -0.176         T1       T32
# 2254862    -0.176         T1       T32
# 2260314    -0.176        NaN       NaN
# 2262813    -0.176         T1       T32
# 2280603    -0.176         T1       T32
# 2284949    -0.176        NaN       NaN
# 2295106    -0.176         T1       T32
# 2304717    -0.176         T1       T32
# 2304749    -0.002         T1      T128
# 2310823     0.081         T1      T128
# 2315493    -0.176         T1       T32
# 2326348     0.030         T1      T128
# 2332054    -0.176         T1       T32
# 2334392    -0.176        NaN       NaN
# 2335856    -0.176         T1       T32
# 2364287    -0.176         T1       T32
#
# [267 rows x 27 columns]

# %%
a=pd.DataFrame(result.L0_S2_F36.value_counts())

# %%
a.sort()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   if __name__ == '__main__':

# %%
a.sort(axis=1)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   if __name__ == '__main__':

# %%
a=a.index

# %%
b=a.values

# %%
b.sort()

# %%
crazy
# Out:
# []

# %%
train
# Out:
#      Id  L0_S0_D1  L0_S0_D3  L0_S0_D5  L0_S0_D7  L0_S0_D9  L0_S0_D11  \
# 0     4     82.24     82.24     82.24     82.24     82.24      82.24
# 1     6       NaN       NaN       NaN       NaN       NaN        NaN
# 2     7   1618.70   1618.70   1618.70   1618.70   1618.70    1618.70
# 3     9   1149.20   1149.20   1149.20   1149.20   1149.20    1149.20
# 4    11    602.64    602.64    602.64    602.64    602.64     602.64
# 5    13   1331.66   1331.66   1331.66   1331.66   1331.66    1331.66
# 6    14       NaN       NaN       NaN       NaN       NaN        NaN
# 7    16       NaN       NaN       NaN       NaN       NaN        NaN
# 8    18    517.64    517.64    517.64    517.64    517.64     517.64
# 9    23       NaN       NaN       NaN       NaN       NaN        NaN
# 10   26   1104.78   1104.78   1104.78   1104.78   1104.78    1104.78
# 11   27    392.85    392.85    392.85    392.85    392.85     392.85
# 12   28     55.44     55.44     55.44     55.44     55.44      55.44
Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2033             return self.take(indexer, axis=0, convert=False)
#    2034         else:
# -> 2035             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2036             return self.take(indexer, axis=1, convert=True)
#    2037
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1212                 mask = check == -1
#    1213                 if mask.any():
# -> 1214                     raise KeyError('%s not in index' % objarr[mask])
#    1215
#    1216                 return _values_from_object(indexer)
#
# KeyError: "['L3_S32_max' 'L3_S32_min'] not in index"

# %%
a=data.L3_S32_max-data.L3_S32_min

# %%
a[a>0]
# Out:
# Series([], dtype: float64)

# %%
data['max']=data.filter(regex=(".*mean")).max(axis=1)

# %%
data.iloc[1,:]
# Out:
# Id                   6.00
# L0_S0_NAcount       12.00
# L0_S0_mean            NaN
# L0_S10_NAcount      13.00
# L0_S10_mean           NaN
# L0_S11_NAcount      13.00
# L0_S11_mean           NaN
# L0_S12_NAcount       0.00
# L0_S12_mean       1313.12
# L0_S13_NAcount       0.00
# L0_S13_mean       1313.12
# L0_S14_NAcount       0.00
# L0_S14_mean       1313.12
# L0_S15_NAcount       9.00
# L0_S15_mean           NaN
# L0_S16_NAcount       0.00
# L0_S16_mean       1313.14
# L0_S17_NAcount       2.00
# L0_S17_mean           NaN
# L0_S18_NAcount       0.00
# L0_S18_mean       1313.15
# L0_S19_NAcount       5.00
# L0_S19_mean           NaN
# L0_S1_NAcount        2.00
# L0_S1_mean            NaN
# L0_S20_NAcount       0.00
# L0_S20_mean       1313.15
# L0_S21_NAcount       0.00
# L0_S21_mean       1313.15
# L0_S22_NAcount      15.00
#                    ...
# L3_S37_mean       1315.75
# L3_S38_NAcount       3.00
# L3_S38_mean           NaN
# L3_S39_NAcount       4.00
# L3_S39_mean           NaN
# L3_S40_NAcount       8.00
# L3_S40_mean           NaN
# L3_S41_NAcount      18.00
# L3_S41_mean           NaN
# L3_S42_NAcount       8.00
# L3_S42_mean           NaN
# L3_S43_NAcount       8.00
# L3_S43_mean           NaN
# L3_S44_NAcount       8.00
# L3_S44_mean           NaN
# L3_S45_NAcount       5.00
# L3_S45_mean           NaN
# L3_S46_NAcount       1.00
# L3_S46_mean           NaN
# L3_S47_NAcount      11.00
# L3_S47_mean           NaN
# L3_S48_NAcount       7.00
# L3_S48_mean           NaN
# L3_S49_NAcount       7.00
# L3_S49_mean           NaN
# L3_S50_NAcount       7.00
# L3_S50_mean           NaN
# L3_S51_NAcount       5.00
# L3_S51_mean           NaN
# ct                   2.63
# Name: 1, dtype: float64

# %%
item in ['L1_S24','L1_S25']
# Out:
# False

# %%
item='L1_S24'
((item=='L1_S24') or (item=='L1_S25'))
# Out:
# True

# %%
a= ['L1_S24','L1_S25']

# %%
item in a
# Out:
# True

# %%
type(a)
# Out:
# list

# %%
item
# Out:
# 'L1_24'

# %%
item==a[0]
# Out:
# False

# %%
a[0]
# Out:
# 'L1_S24'
