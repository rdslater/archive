# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
path='c://Users//Robert//Downloads//nyt1.csv'
data1=pd.DataFrame(pd.read_csv(path))
data1['age_cat']='a'
data1['age_cat']=np.where(data1['Age']==0,'0',data1['age_cat'])
data1['age_cat']=np.where(data1['Age']<0,'<0',data1['age_cat'])
data1['age_cat']=np.where(np.logical_and(data1['Age']>0,data1['Age']<=18),'1-18',data1['age_cat'])
data1['age_cat']=np.where(np.logical_and(data1['Age']>18,data1['Age']<=25),'19-25',data1['age_cat'])
data1['age_cat']=np.where(np.logical_and(data1['Age']>25,data1['Age']<=35),'26-35',data1['age_cat'])
data1['age_cat']=np.where(np.logical_and(data1['Age']>35,data1['Age']<=45),'36-45',data1['age_cat'])
data1['age_cat']=np.where(np.logical_and(data1['Age']>45,data1['Age']<=55),'46-55',data1['age_cat'])
data1['age_cat']=np.where(np.logical_and(data1['Age']>55,data1['Age']<=65),'56-65',data1['age_cat'])
data1['age_cat']=np.where(data1['Age']>65,'65+',data1['age_cat'])
data1
# Out:
#         Age  Gender  Impressions  Clicks  Signed_In age_cat
# 0        36       0            3       0          1   36-45
# 1        73       1            3       0          1     65+
# 2        30       0            3       0          1   26-35
# 3        49       1            3       0          1   46-55
# 4        47       1           11       0          1   46-55
# 5        47       0           11       1          1   46-55
# 6         0       0            7       1          0       0
# 7        46       0            5       0          1   46-55
# 8        16       0            3       0          1    1-18
# 9        52       0            4       0          1   46-55
# 10        0       0            8       1          0       0
# 11       21       0            3       0          1   19-25
# 12        0       0            4       0          0       0
# 13       57       0            6       0          1   56-65
# 14       31       0            5       0          1   26-35
# 15        0       0            6       0          0       0
# 16       40       1            3       0          1   36-45
# 17       31       1            5       0          1   26-35
# 18       38       0            4       0          1   36-45
# 19        0       0            5       0          0       0
# 20       59       1            4       0          1   56-65
# 21       61       0            6       0          1   56-65
# 22       48       0            7       0          1   46-55
# 23       29       1            2       0          1   26-35
# 24        0       0            4       0          0       0
# 25       19       1            4       0          1   19-25
# 26       19       0            3       0          1   19-25
# 27       48       1            9       0          1   46-55
# 28       48       1            4       0          1   46-55
# 29       21       1            5       0          1   19-25
# ...     ...     ...          ...     ...        ...     ...
# 458411   55       1            2       0          1   46-55
# 458412   68       1            7       0          1     65+
# 458413    0       0            7       1          0       0
# 458414   21       0            5       0          1   19-25
# 458415   35       0            6       0          1   26-35
# 458416   26       1            6       0          1   26-35
# 458417   41       0           11       0          1   36-45
# 458418   58       1            4       0          1   56-65
# 458419   46       1            5       0          1   46-55
# 458420   45       0           11       0          1   36-45
# 458421   46       1            4       0          1   46-55
# 458422   47       0            6       0          1   46-55
# 458423   22       1            8       0          1   19-25
# 458424   21       0           10       0          1   19-25
# 458425   40       1            6       0          1   36-45
# 458426   49       0            9       0          1   46-55
# 458427   43       1            9       0          1   36-45
# 458428   40       1            4       0          1   36-45
# 458429   49       1           11       0          1   46-55
# 458430    0       0            6       0          0       0
# 458431   21       1            5       0          1   19-25
# 458432   30       0            4       0          1   26-35
# 458433   21       1            2       0          1   19-25
# 458434   61       1            6       0          1   56-65
# 458435   51       0            7       0          1   46-55
# 458436    0       0            2       0          0       0
# 458437    0       0            4       0          0       0
# 458438   72       1            5       0          1     65+
# 458439    0       0            5       0          0       0
# 458440    0       0            3       0          0       0
#
# [458441 rows x 6 columns]

# %%
data2=np.array(pd.DataFrame(data1.loc[data1['age_cat'] == '0','Impressions']))
data3=np.array(pd.DataFrame(data1.loc[data1['age_cat'] == '1-18','Impressions']))
data4=np.array(pd.DataFrame(data1.loc[data1['age_cat'] == '19-25','Impressions']))
data5=np.array(pd.DataFrame(data1.loc[data1['age_cat'] == '26-35','Impressions']))
data6=np.array(pd.DataFrame(data1.loc[data1['age_cat'] == '36-45','Impressions']))

# %%
f=ggplot(data1,aes(x='Impressions',fill='age_cat'))+geom_histogram(binwidth=1)
f
# Out:
# C:\Anaconda3\lib\site-packages\ggplot\geoms\geom_bar.py:47: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   _reset = self.bottom == None or (self.ax != None and self.ax != ax)
# <ggplot: (-9223372036834554480)>

# %%
data1.head(10)
p=ggplot(data1,aes('Clicks','Impressions'))
f= p + geom_point()
f
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
# <ggplot: (-9223372036831573679)>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-c7ac0eba6c6a> in <module>()
# ----> 1 qplot('mpg', 'drat', data=data1, log='y', main="log y")
#
# C:\Anaconda3\lib\site-packages\ggplot\qplot.py in qplot(x, y, color, size, fill, data, geom, stat, position, xlim, ylim, log, main, xlab, ylab, asp)
#     112         geom = geom_map.get(geom, geom_point)
#     113
# --> 114     p = ggplot.ggplot(_aes, data=data) + geom()
#     115     if "x" in log:
#     116         p += scale_x_log()
#
# C:\Anaconda3\lib\site-packages\ggplot\ggplot.py in __init__(self, aesthetics, data)
#      64
#      65         self.aesthetics = aesthetics
# ---> 66         self.data = _apply_transforms(data, self.aesthetics)
#      67
#      68         # defaults
#
# C:\Anaconda3\lib\site-packages\ggplot\ggplot.py in _apply_transforms(data, aes)
#     548             env = EvalEnvironment.capture(eval_env=(aes.__eval_env__ or 1))
#     549             # add factor as a special case
# --> 550             env.add_outer_namespace({"factor":factor})
#     551             try:
#     552                 new_val = env.eval(name, inner_namespace=data)
#
# AttributeError: 'EvalEnvironment' object has no attribute 'add_outer_namespace'
